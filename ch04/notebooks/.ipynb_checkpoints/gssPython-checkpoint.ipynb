# %% [markdown]
# # Exploring GSS 2016 for ABM

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
import os
# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/Users/sdaza/GoogleDrive/00Dissertation/dissertation_github'

# %%
df = pd.read_stata('abm/data/GSS2016.DTA', convert_categoricals=False)

# %%
df.columns
# Out:
# Index(['mar1', 'mar2', 'mar3', 'mar4', 'mar5', 'mar6', 'mar7', 'mar8', 'mar9',
#        'mar10',
#        ...
#        'barate', 'gradtounder', 'spsector', 'speftotlt', 'spbarate',
#        'spgradtounder', 'cosector', 'coeftotlt', 'cobarate', 'cogradtounder'],
#       dtype='object', length=960)

# %%
df_sel.loc[:, 'educ'].hist();

# %%
df_sel.loc[:, 'age'].hist()

# %%
df_sel = df.loc[:, ['age', 'realrinc', 'educ']].dropna()

# %%
sns.jointplot(x="educ", y="realrinc", data=df_sel, alpha=0.3);

# %%
df_sel.columns = ['age', 'income', 'educ']

# %%
df_sel.to_excel('agents_data.xlsx', index=False)

# %%
# Resampling values

# %%
# s = df_sel.sample(n=10000, replace=True)

# %%
# s['id'] = range(s.shape[0])

# %%
# s.loc[:, ['id', 'age', 'income', 'educ']].to_excel('agents_data.xlsx', index=False)
